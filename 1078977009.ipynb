# %% [markdown]
# <a href="https://colab.research.google.com/github/hsandaver/hsandaver.github.io/blob/main/1078977009.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Condition report with reflectance, abosorbance and CIELAB Tristimulus Values

# %% [markdown]
# **OCLC No. 1078977009**
#
# Moran, Patrick Francis. *History of the Catholic Church in Australasia, from Authentic Sources*. Sydney: Oceanic Publishing Company, 1894.

# %% [markdown]
# [3D Model of Binding](https://skfb.ly/ouTVr)

# %% [markdown]
# # Reflectance and Absorbance Spectra

# %% [markdown]
# Reflectance spectra for binding (for image see [3D Model](https://skfb.ly/ouTVr))

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.03]
y2 = [0.05]
y3 = [0.10]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for History of the Catholic Church in Australasia (Binding) 2022-06-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=800, height=600) 

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="ef63058c-10ad-42de-9239-7880ec92fba3" data-root-id="1802"></div>

# %% [markdown]
# Absorbance spectra for binding (area with no gold tooling)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.44]
y2 = [0.412]
y3 = [0.246]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for History of the Catholic Church in Australasia (Binding) 2022-06-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=800, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="60f67002-d8b7-4b55-bbd1-0e4812084300" data-root-id="2004"></div>

# %% [markdown]
# **Reflectance spectra for Title page**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.55]
y2 = [0.72]
y3 = [0.81]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for History of the Catholic Church in Australasia (Title page) 2022-06-07", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=800, height=600) 

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="f8e79d7f-4e44-4ee7-9ec3-59974f01a942" data-root-id="1002"></div>

# %% [markdown]
# **Absorbance spectra for Title page**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.03]
y2 = [-0.16]
y3 = [-0.052]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for History of the Catholic Church in Australasia (Binding) 2022-06-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=800, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="b0b9275b-2811-4077-8e36-32924932515f" data-root-id="1134"></div>

# %% [markdown]
# # Tristimulus values

# %% [markdown]
# Tristimulus values for Title page

# %% [markdown]
# ![Screen Shot 2022-06-07 at 11.56.39 am.png](data:image/png;base64,...)

# %%
from bokeh.io import output_file, show, output_notebook
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge

output_file("dodged_bars.html")

fruits = ['Aged 128 Years', 'Aged 129 Years']
years = ['L', 'a', 'b']

data = {'fruits' : fruits,
        'L'   : [90.82, 0],
        'a'   : [-0.44, 0],
        'b'   : [6.67, 0]}

source = ColumnDataSource(data=data)

p = figure(x_range=fruits, y_range=(-10, 127), height=600, title="CIE LAB Tristimulus Values for Title page",
           toolbar_location=None, tools="")

p.vbar(x=dodge('fruits', -0.25, range=p.x_range), top='L', width=0.2, source=source,
       color="#c9d9d3", legend_label="L")

p.vbar(x=dodge('fruits',  0.0,  range=p.x_range), top='a', width=0.2, source=source,
       color="#718dbf", legend_label="a")

p.vbar(x=dodge('fruits',  0.25, range=p.x_range), top='b', width=0.2, source=source,
       color="#e84d60", legend_label="b")

p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)
# Out:
#   <div class="bk-root" id="90ff6dde-bcb3-4d3a-90f0-e852e33a848c" data-root-id="1281"></div>
