# %% [markdown]
# <a href="https://colab.research.google.com/github/hsandaver/hsandaver.github.io/blob/main/2756214.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Reflectance Dataset and Absorbance Dataset**

# %% [markdown]
# **OCLC No.: 2756214**
#
# Wight, J, Andrew Agnew, George Cruikshank, Effingham Wilson, Thomas Hurst, John Thompson, Samuel Williams, et al. *Sunday in London*. London: Effingham Wilson, 1833.

# %% [markdown]
# 2022-05-06

# %% [markdown]
# **Cover**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [2]
y2 = [4]
y3 = [7]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Cover) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="3f6473c9-3b7c-4895-8bb7-007d769aebb7" data-root-id="1642"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.46]
y2 = [0.26]
y3 = [0.17]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Cover) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="bceae09e-ffa9-40fd-acdb-d46afc2a05d5" data-root-id="1774"></div>

# %% [markdown]
# **Endpapers**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [4]
y2 = [8]
y3 = [12]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Endpapers) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="bbf28e7b-1e0b-4750-82fc-5bff827dec87" data-root-id="1920"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.58]
y2 = [0.03]
y3 = [0.18]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Endpapers) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="b579cc86-694e-4b21-be6c-e25c2390c867" data-root-id="2080"></div>

# %% [markdown]
# **Flyleaf (inscribed)**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [62]
y2 = [82]
y3 = [94]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Inscribed Flyleaf) 2022-05-06", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="cb0f42c9-bb1d-445a-b011-55e75113144e" data-root-id="2254"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.08]
y2 = [-0.17]
y3 = [-0.09]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Inscribed Flyleaf) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="d723b477-8bb8-4116-9d92-d90c8447eaf7" data-root-id="2442"></div>

# %% [markdown]
# **Plate 1**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [36]
y2 = [42]
y3 = [46]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 1) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="94997a00-00b6-490f-9e15-4127ab511855" data-root-id="2644"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.10]
y2 = [-0.16]
y3 = [-0.10]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 1) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="60f26cfd-bf3f-4e3d-ace2-40b4bb507fc4" data-root-id="2860"></div>

# %% [markdown]
# **Guard Sheet**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [54]
y2 = [64]
y3 = [70]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Guard Sheet) 2022-05-06", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="06a2ea62-a8c2-4817-89a9-f5fae80b5923" data-root-id="3090"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.06]
y2 = [-0.15]
y3 = [-0.08]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Guard Sheet) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="60852ded-ca1c-49de-88f6-b545d7923ad3" data-root-id="3334"></div>

# %% [markdown]
# **Title page**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [50]
y2 = [60]
y3 = [64]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Title page) 2022-05-06", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="8d037268-870c-4366-8be4-d9818b71c685" data-root-id="3592"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.08]
y2 = [-0.15]
y3 = [-0.05]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Title page) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="63230386-a854-45b3-9136-803bf1c556e3" data-root-id="3864"></div>

# %% [markdown]
# **Leaf A**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [61]
y2 = [74]
y3 = [82]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Leaf A) 2022-05-06", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="349af04a-5253-4967-abd2-570b67ea39f1" data-root-id="4150"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.10]
y2 = [-0.16]
y3 = [-0.09]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Leaf A) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="c71fb9fd-5550-469b-a8b2-15f4a044d5a2" data-root-id="4450"></div>

# %% [markdown]
# **Plate 2**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [30]
y2 = [36]
y3 = [41]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 2) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="7f3b2f8d-c997-4b71-aaa1-488ba8297fba" data-root-id="4764"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.14]
y2 = [-0.12]
y3 = [-0.07]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 2) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="7ac842db-4f1e-407e-bf14-2b6a091d61cb" data-root-id="5092"></div>

# %% [markdown]
# **Plate 3**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [32]
y2 = [39]
y3 = [42]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 3) 2022-05-06", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="c2fedff6-ca27-4db0-b97a-1edb413866c1" data-root-id="5434"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.12]
y2 = [-0.17]
y3 = [-0.08]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 3) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="10d02dcc-46cb-4d32-982c-1ea5a11fb59e" data-root-id="5790"></div>

# %% [markdown]
# **Plate 4**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [20]
y2 = [24]
y3 = [28]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 4) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="43791152-4af6-4734-bfd9-463dad7e4517" data-root-id="6160"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.03]
y2 = [-0.08]
y3 = [-0.09]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 4) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="6d26c355-8df0-4139-8e06-00c343508dec" data-root-id="6544"></div>

# %% [markdown]
# **Plate 5**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [26]
y2 = [31]
y3 = [35]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 5) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="8dcbf2e4-4baa-4b2b-9520-ca2a16e1a0b1" data-root-id="6942"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.02]
y2 = [-0.16]
y3 = [-0.08]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 5) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="81282871-766f-4f90-a4f5-03f837f3a004" data-root-id="7354"></div>

# %% [markdown]
# **Plate 6**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [19]
y2 = [24]
y3 = [27]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 6) 2022-05-06", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="71e89cd1-4797-4681-844c-55cb4668691a" data-root-id="7780"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.00]
y2 = [-0.15]
y3 = [-0.09]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 6) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="cd22a0de-f1b8-4301-b17f-4b310710c782" data-root-id="8220"></div>

# %% [markdown]
# **Plate 7**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [21]
y2 = [26]
y3 = [30]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 7) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="1fe3e087-c399-47f7-b041-c0050ca6b8e4" data-root-id="8674"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.01]
y2 = [-0.14]
y3 = [-0.09]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 7) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="a4228370-0a2a-4b69-9ea6-990d22e6ae5a" data-root-id="9142"></div>

# %% [markdown]
# **Page 34 (letterpress with illustration)**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [44]
y2 = [54]
y3 = [59]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (page 34) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="b1d6aa47-0065-4188-abbf-7273963794bd" data-root-id="9624"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.02]
y2 = [-0.15]
y3 = [-0.08]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (page 34) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="2a5af8ed-9632-4f57-9182-8b8fc6eb8213" data-root-id="10120"></div>

# %% [markdown]
# **Page 35 (letterpress with illustration)**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [49]
y2 = [61]
y3 = [67]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (page 35) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="2757bc0a-4aa8-487c-9fc0-13e68acf4785" data-root-id="10630"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.03]
y2 = [-0.10]
y3 = [-0.08]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (page 35) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="69b21069-e1b3-4d27-ace2-9760b7f25791" data-root-id="11154"></div>

# %% [markdown]
# **Plate 8**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [32]
y2 = [39]
y3 = [44]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 8) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="f69b38e0-55ea-4e4b-bf0f-d3139505db1f" data-root-id="11692"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.03]
y2 = [-0.08]
y3 = [-0.05]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 8) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="158d33c8-55cb-4626-8141-7303fb3672cd" data-root-id="12244"></div>

# %% [markdown]
# **Plate 9**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [39]
y2 = [45]
y3 = [49]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 9) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="429b4e8a-36d9-440c-bc05-8f6b81436d71" data-root-id="12810"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.01]
y2 = [-0.12]
y3 = [-0.06]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 9) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="e0c9db0b-b15b-4949-b43b-615182d3e05e" data-root-id="13390"></div>

# %% [markdown]
# **Page 44 (letterpress with illustration)**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [39]
y2 = [45]
y3 = [49]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (page 44) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="b747991a-cd37-45ca-9b6b-361abd2a9915" data-root-id="13984"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.05]
y2 = [-0.11]
y3 = [-0.06]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (page 44) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="e79e2b6e-ae3d-4f45-8d6d-54c9c6ee3496" data-root-id="14592"></div>

# %% [markdown]
# **Plate 10**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [28]
y2 = [35]
y3 = [39]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 10) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="bd1cf4f3-8984-480e-a438-e8113e747f54" data-root-id="15214"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.02]
y2 = [-0.10]
y3 = [-0.07]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 10) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="a498c6d6-9e8b-425d-bce4-fa65bc26ba77" data-root-id="15850"></div>

# %% [markdown]
# **Plate 11**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [37]
y2 = [44]
y3 = [49]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 11) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="964f0228-0ed1-4832-9574-a2269acc9eb4" data-root-id="16500"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.01]
y2 = [-0.09]
y3 = [-0.07]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 11) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="e5f44332-9611-4ec9-bee5-f24498d61e18" data-root-id="17164"></div>

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
import numpy as np
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.transform import dodge
from bokeh.palettes import GnBu3, OrRd3

fruits = ['189 years', '190 Years', '191 years', '192 years', '193 years', '194 years']
counts = [99.60, 0, 0, 0, 0, 0]

source = ColumnDataSource(data=dict(fruits=fruits, counts=counts, color=Spectral6))

p = figure(x_range=fruits, y_range=(0,127), height=600, title="L values over time",
           toolbar_location=None, tools="")

p.vbar(x='fruits', top='counts', width=0.9, color='color', legend_field="fruits", source=source)

p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-1756b5669273> in <module>()
#       9 counts = [99.60, 0, 0, 0, 0, 0]
#      10
# ---> 11 source = ColumnDataSource(data=dict(fruits=fruits, counts=counts, color=Spectral6))
#      12
#      13 p = figure(x_range=fruits, y_range=(0,127), height=600, title="L values over time",
#
# NameError: name 'Spectral6' is not defined

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
import numpy as np
from bokeh.models import ColumnDataSource, FactorRange
from bokeh.transform import dodge
from bokeh.palettes import GnBu3, OrRd3

fruits = ['189 years', '190 Years', '191 years', '192 years', '193 years', '194 years']
counts = [-2.19, 0, 0, 0, 0, 0]

source = ColumnDataSource(data=dict(fruits=fruits, counts=counts, color=Spectral6))

p = figure(x_range=fruits, y_range=(-3,3), height=600, title="a values over time",
           toolbar_location=None, tools="")

p.vbar(x='fruits', top='counts', width=0.9, color='color', legend_field="fruits", source=source)

p.xgrid.grid_line_color = None
p.legend.orientation = "horizontal"
p.legend.location = "top_center"

show(p)

# %%
from bokeh.io import output_file, show, output_notebook
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge

output_file("dodged_bars.html")

fruits = ['Aged 189 Years', 'Aged 190 Years']
years = ['L', 'a', 'b']

data = {'fruits' : fruits,
        'L'   : [99.6, 0],
        'a'   : [-2.19, 0],
        'b'   : [4.58, 0]}

source = ColumnDataSource(data=data)

p = figure(x_range=fruits, y_range=(-10, 127), height=800, title="CIE LAB Tristimulus Values for Title Page",
           toolbar_location=None, tools="")

p.vbar(x=dodge('fruits', -0.25, range=p.x_range), top='L', width=0.2, source=source,
       color="#c9d9d3", legend_label="L")

p.vbar(x=dodge('fruits',  0.0,  range=p.x_range), top='a', width=0.2, source=source,
       color="#718dbf", legend_label="a")

p.vbar(x=dodge('fruits',  0.25, range=p.x_range), top='b', width=0.2, source=source,
       color="#e84d60", legend_label="b")

p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)
# Out:
#   <div class="bk-root" id="62c46792-6924-479b-bcec-984845657df8" data-root-id="26078"></div>
