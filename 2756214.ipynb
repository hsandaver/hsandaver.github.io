# %% [markdown]
# <a href="https://colab.research.google.com/github/hsandaver/hsandaver.github.io/blob/main/2756214.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Condition report with reflectance and absorbance datasets**

# %% [markdown]
# **OCLC No.: 2756214**
#
# Wight, J, Andrew Agnew, George Cruikshank, Effingham Wilson, Thomas Hurst, John Thompson, Samuel Williams, et al. *Sunday in London*. London: Effingham Wilson, 1833.

# %% [markdown]
# 2022-05-06

# %% [markdown]
# **Binding**
#
# Bound in late nineteenth century brown goatskin with gold tooling on cover.
#
# [Condition review as 3D Scan](https://skfb.ly/ousUt)

# %% [markdown]
# **Reflectance of Binding**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [2]
y2 = [4]
y3 = [7]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Binding) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="19cc0191-129b-4196-a476-cd418589f1b0" data-root-id="1002"></div>

# %% [markdown]
# **Absorbance of binding**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.46]
y2 = [0.26]
y3 = [0.17]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Binding) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="7811e0e6-ead9-4c91-aae3-f104ad85dae0" data-root-id="1134"></div>

# %% [markdown]
# **Endpapers**
#
# Endpapers are marbled with French Shell pattern with bookplate of unknown provenance adhered on verso of the cover.
#
# ![IMG_0001.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Reflectance of endpapers**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [4]
y2 = [8]
y3 = [12]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Endpapers) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="54789495-36d0-4096-a797-6a9902d4b6fa" data-root-id="1280"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.58]
y2 = [0.03]
y3 = [0.18]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Endpapers) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="9dbc7933-81ce-4218-9f95-61c1b47069f2" data-root-id="1440"></div>

# %% [markdown]
# **Flyleaf (inscribed)**
#
# ![IMG_0002.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [62]
y2 = [82]
y3 = [94]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Inscribed Flyleaf) 2022-05-06", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="4b74f04f-d9f7-4a4b-9f90-f41cf3503f31" data-root-id="1614"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.08]
y2 = [-0.17]
y3 = [-0.09]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Inscribed Flyleaf) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="56493525-5f63-472e-b8b4-e56d930a3c6f" data-root-id="1802"></div>

# %% [markdown]
# **Plate 1**
#
# ![IMG_0003.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [36]
y2 = [42]
y3 = [46]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 1) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="eba599a8-6a79-4ec4-ba41-d8f59882b99a" data-root-id="2004"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.10]
y2 = [-0.16]
y3 = [-0.10]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 1) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="d2c0850d-8fb4-4b82-85ea-f7a41d9cc870" data-root-id="2220"></div>

# %% [markdown]
# **Guard Sheet**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [54]
y2 = [64]
y3 = [70]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Guard Sheet) 2022-05-06", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="0a7edaa3-165a-42a7-982b-9dd57d16fa2a" data-root-id="2450"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.06]
y2 = [-0.15]
y3 = [-0.08]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Guard Sheet) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="e2189507-43a6-4bd6-878e-1086058a6c9a" data-root-id="2694"></div>

# %% [markdown]
# **Title page**
#
# ![IMG_0004.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [50]
y2 = [60]
y3 = [64]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Title page) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="e7a23f8c-d2a7-44d0-b133-61194ad282e0" data-root-id="2952"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.08]
y2 = [-0.15]
y3 = [-0.05]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Title page) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="a552ad1b-f439-4616-821a-3ed3a8ddd2a6" data-root-id="3224"></div>

# %% [markdown]
# **Leaf A**
#
# ![IMG_0005.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [61]
y2 = [74]
y3 = [82]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Leaf A) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="bab19043-715f-4601-a16c-b5c2ed3ae412" data-root-id="3510"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.10]
y2 = [-0.16]
y3 = [-0.09]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Leaf A) 2022-05-09", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="02a1cbce-0756-430d-a9fb-281906c40a86" data-root-id="3810"></div>

# %% [markdown]
# **Plate 2**
#
# ![IMG_0006.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [30]
y2 = [36]
y3 = [41]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 2) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="db121989-8caa-46e0-9c1a-7bd44c6c6b92" data-root-id="4124"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.14]
y2 = [-0.12]
y3 = [-0.07]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 2) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="8acc237c-0eb8-4841-97e9-692a1c1dcb46" data-root-id="4452"></div>

# %% [markdown]
# **Plate 3**
#
# ![IMG_0007.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [32]
y2 = [39]
y3 = [42]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 3) 2022-05-06", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="e3f8fc28-bedf-4c69-b105-342f2be7455f" data-root-id="4794"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.12]
y2 = [-0.17]
y3 = [-0.08]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 3) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="49343fa4-e859-4bfb-8cd4-267f80cbc508" data-root-id="5150"></div>

# %% [markdown]
# **Plate 4**
#
# ![IMG_0008.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [20]
y2 = [24]
y3 = [28]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 4) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="6559c43d-2211-4db0-84a4-dacde66bb34e" data-root-id="5520"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.03]
y2 = [-0.08]
y3 = [-0.09]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 4) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="ab5d545d-42fa-4598-960a-8f8d82b99dc4" data-root-id="5904"></div>

# %% [markdown]
# **Plate 5**
#
# ![IMG_0009.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [26]
y2 = [31]
y3 = [35]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 5) 2022-05-06", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="8da6f825-de68-4e90-a639-196c14d2cce0" data-root-id="6302"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.02]
y2 = [-0.16]
y3 = [-0.08]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 5) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="25bbeb44-7665-4531-b01b-60147c4e3aca" data-root-id="6714"></div>

# %% [markdown]
# **Plate 6**
#
# ![IMG_0010.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [19]
y2 = [24]
y3 = [27]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 6) 2022-05-06", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="918b3a03-626d-4c8c-bc43-fa6e47aff791" data-root-id="7140"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.00]
y2 = [-0.15]
y3 = [-0.09]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 6) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="fa799620-0825-4e2f-98dd-782f1903b449" data-root-id="7580"></div>

# %% [markdown]
# **Plate 7**
#
# ![IMG_0011.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [21]
y2 = [26]
y3 = [30]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 7) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="54e310cd-b7a0-49d8-85a1-b2afbac87695" data-root-id="8034"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.01]
y2 = [-0.14]
y3 = [-0.09]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 7) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="130e3af3-60a8-4c5a-9295-0e9985899873" data-root-id="8502"></div>

# %% [markdown]
# **Page 34 (letterpress with illustration)**
#
# ![IMG_0012.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [44]
y2 = [54]
y3 = [59]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (page 34) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="0ff681ef-860e-4948-8a25-2f4116e6152b" data-root-id="8984"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.02]
y2 = [-0.15]
y3 = [-0.08]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (page 34) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="d45f9ea1-9c9a-4e81-b7f9-cf750d58bd5f" data-root-id="9480"></div>

# %% [markdown]
# **Page 35 (letterpress with illustration)**

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [49]
y2 = [61]
y3 = [67]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (page 35) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="4a98b9b5-362f-496f-8eb1-5a5f4a1f4042" data-root-id="9990"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.03]
y2 = [-0.10]
y3 = [-0.08]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (page 35) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="bf0cae69-4773-4775-a46e-ba44cffbf514" data-root-id="10514"></div>

# %% [markdown]
# **Plate 8**
#
# ![IMG_0013.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [32]
y2 = [39]
y3 = [44]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 8) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="04938c4d-5d8b-4694-8dbf-ea62c13de890" data-root-id="11052"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.03]
y2 = [-0.08]
y3 = [-0.05]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 8) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="8e03e5f8-4af8-43af-ac92-c105a4ae1211" data-root-id="11604"></div>

# %% [markdown]
# **Plate 9**
#
# ![IMG_0014.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [39]
y2 = [45]
y3 = [49]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 9) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="80b53cc3-0755-4fbf-bb7c-7725c44dd30a" data-root-id="12170"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.01]
y2 = [-0.12]
y3 = [-0.06]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 9) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="a9ee931f-51d3-4fb9-acfc-072773a07f6c" data-root-id="12750"></div>

# %% [markdown]
# **Page 44 (letterpress with illustration)**
#
# ![IMG_0015.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [39]
y2 = [45]
y3 = [49]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (page 44) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="75601fc2-dafa-44b2-82af-e352e1d9395c" data-root-id="13344"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.05]
y2 = [-0.11]
y3 = [-0.06]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (page 44) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="efffe611-fde0-42c9-a399-b17cca7dc5ed" data-root-id="13952"></div>

# %% [markdown]
# **Plate 10**
#
# ![IMG_0016.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [28]
y2 = [35]
y3 = [39]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 10) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="68b68b82-caa4-408d-bc19-42444253c2a7" data-root-id="14574"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [0.02]
y2 = [-0.10]
y3 = [-0.07]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 10) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="853664dd-35bd-4285-9d06-4918663b1fb6" data-root-id="15210"></div>

# %% [markdown]
# **Plate 11**
#
# ![IMG_0017.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [37]
y2 = [44]
y3 = [49]

# create a new plot with a title and axis labels
p = figure(title="Reflectance spectra for Sunday in London (Plate 11) 2022-05-09", x_axis_label="WAVELENGTH, nm", y_axis_label="% REFLECTANCE", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="fc843f5e-0e79-4588-ada3-738195897acc" data-root-id="15860"></div>

# %%
import numpy as np
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

# Call once to configure Bokeh to display plots inline in the notebook.
output_notebook()

# prepare some data
x1 = [460]
x2 = [550]
x3 = [640]
y1 = [-0.01]
y2 = [-0.09]
y3 = [-0.07]

# create a new plot with a title and axis labels
p = figure(title="Absorbance spectra for Sunday in London (Plate 11) 2022-05-10", 
           x_axis_label="WAVELENGTH, nm", y_axis_label="ABSORBANCE (% max)", width=600, height=600)

# add multiple renderers
p.diamond(x=x1, y=y1, size=15, color="Blue", line_width=2)
p.diamond(x=x2, y=y2, size=15, color="Green", line_width=2)
p.diamond(x=x3, y=y3, size=15, color="Red", line_width=2)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="5c3cfdc1-d4cc-473d-85d1-585d5e03f5ac" data-root-id="16524"></div>

# %%
from bokeh.io import output_file, show, output_notebook
from bokeh.models import ColumnDataSource
from bokeh.plotting import figure
from bokeh.transform import dodge

output_file("dodged_bars.html")

fruits = ['Aged 189 Years', 'Aged 190 Years']
years = ['L', 'a', 'b']

data = {'fruits' : fruits,
        'L'   : [90.79, 0],
        'a'   : [1.78, 0],
        'b'   : [11.83, 0]}

source = ColumnDataSource(data=data)

p = figure(x_range=fruits, y_range=(-10, 127), height=600, title="CIE LAB Tristimulus Values for Title Page",
           toolbar_location=None, tools="")

p.vbar(x=dodge('fruits', -0.25, range=p.x_range), top='L', width=0.2, source=source,
       color="#c9d9d3", legend_label="L")

p.vbar(x=dodge('fruits',  0.0,  range=p.x_range), top='a', width=0.2, source=source,
       color="#718dbf", legend_label="a")

p.vbar(x=dodge('fruits',  0.25, range=p.x_range), top='b', width=0.2, source=source,
       color="#e84d60", legend_label="b")

p.x_range.range_padding = 0.1
p.xgrid.grid_line_color = None
p.legend.location = "top_left"
p.legend.orientation = "horizontal"

show(p)
# Out:
#   <div class="bk-root" id="8309c238-a2ef-4be3-92e1-3e0d3dd50eca" data-root-id="17203"></div>
